# %%
import os, getpass

# %%
def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("GEMINI_API_KEY")
# Out:
# GEMINI_API_KEY:  ········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
    temperature = 0
)

# %%
# !pip install RealTimeSTT
# Out:
# Requirement already satisfied: RealTimeSTT in /opt/anaconda3/lib/python3.13/site-packages (0.3.104)
# Requirement already satisfied: PyAudio==0.2.14 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (0.2.14)
# Requirement already satisfied: faster-whisper==1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (1.1.1)
# Requirement already satisfied: pvporcupine==1.9.5 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (1.9.5)
# Requirement already satisfied: webrtcvad-wheels==2.0.14 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (2.0.14)
# Requirement already satisfied: halo==0.0.31 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (0.0.31)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (2.10.0)
# Requirement already satisfied: torchaudio in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (2.10.0)
# Requirement already satisfied: scipy==1.15.2 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (1.15.2)
# Requirement already satisfied: openwakeword>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (0.6.0)
# Requirement already satisfied: websockets==15.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (15.0.1)
# Requirement already satisfied: websocket-client==1.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (1.8.0)
# Requirement already satisfied: soundfile==0.13.1 in /opt/anaconda3/lib/python3.13/site-packages (from RealTimeSTT) (0.13.1)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealTimeSTT) (4.7.1)
# Requirement already satisfied: huggingface-hub>=0.13 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealTimeSTT) (1.4.1)
# Requirement already satisfied: tokenizers<1,>=0.13 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealTimeSTT) (0.22.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealTimeSTT) (1.24.2)
# Requirement already satisfied: av>=11 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealTimeSTT) (16.1.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealTimeSTT) (4.67.1)
# Requirement already satisfied: log_symbols>=0.0.14 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealTimeSTT) (0.0.14)
# Requirement already satisfied: spinners>=0.0.24 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealTimeSTT) (0.0.24)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealTimeSTT) (3.3.0)
# Requirement already satisfied: colorama>=0.3.9 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealTimeSTT) (0.4.6)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealTimeSTT) (1.17.0)
# Requirement already satisfied: enum34 in /opt/anaconda3/lib/python3.13/site-packages (from pvporcupine==1.9.5->RealTimeSTT) (1.1.10)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from pvporcupine==1.9.5->RealTimeSTT) (2.1.3)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/lib/python3.13/site-packages (from soundfile==0.13.1->RealTimeSTT) (1.17.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1->RealTimeSTT) (82.0.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in /opt/anaconda3/lib/python3.13/site-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1->RealTimeSTT) (6.0.2)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealTimeSTT) (25.12.19)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealTimeSTT) (24.2)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealTimeSTT) (6.33.5)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealTimeSTT) (1.13.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (0.28.1)
# Requirement already satisfied: shellingham in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (1.5.0)
# Requirement already satisfied: typer-slim in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (4.15.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (4.12.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (0.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.0->soundfile==0.13.1->RealTimeSTT) (2.21)
# Requirement already satisfied: scikit-learn<2,>=1 in /opt/anaconda3/lib/python3.13/site-packages (from openwakeword>=0.4.0->RealTimeSTT) (1.6.1)
# Requirement already satisfied: requests<3,>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from openwakeword>=0.4.0->RealTimeSTT) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0->openwakeword>=0.4.0->RealTimeSTT) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0->openwakeword>=0.4.0->RealTimeSTT) (2.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2,>=1->openwakeword>=0.4.0->RealTimeSTT) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2,>=1->openwakeword>=0.4.0->RealTimeSTT) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealTimeSTT) (1.3.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch->RealTimeSTT) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch->RealTimeSTT) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch->RealTimeSTT) (3.0.2)
# Requirement already satisfied: typer>=0.24.0 in /opt/anaconda3/lib/python3.13/site-packages (from typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealTimeSTT) (0.1.0)

# %%
import sys
# !{sys.executable} -m pip install RealtimeSTT
# Out:
# Requirement already satisfied: RealtimeSTT in /opt/anaconda3/lib/python3.13/site-packages (0.3.104)
# Requirement already satisfied: PyAudio==0.2.14 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (0.2.14)
# Requirement already satisfied: faster-whisper==1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (1.1.1)
# Requirement already satisfied: pvporcupine==1.9.5 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (1.9.5)
# Requirement already satisfied: webrtcvad-wheels==2.0.14 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (2.0.14)
# Requirement already satisfied: halo==0.0.31 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (0.0.31)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (2.10.0)
# Requirement already satisfied: torchaudio in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (2.10.0)
# Requirement already satisfied: scipy==1.15.2 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (1.15.2)
# Requirement already satisfied: openwakeword>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (0.6.0)
# Requirement already satisfied: websockets==15.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (15.0.1)
# Requirement already satisfied: websocket-client==1.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (1.8.0)
# Requirement already satisfied: soundfile==0.13.1 in /opt/anaconda3/lib/python3.13/site-packages (from RealtimeSTT) (0.13.1)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealtimeSTT) (4.7.1)
# Requirement already satisfied: huggingface-hub>=0.13 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealtimeSTT) (1.4.1)
# Requirement already satisfied: tokenizers<1,>=0.13 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealtimeSTT) (0.22.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealtimeSTT) (1.24.2)
# Requirement already satisfied: av>=11 in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealtimeSTT) (16.1.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from faster-whisper==1.1.1->RealtimeSTT) (4.67.1)
# Requirement already satisfied: log_symbols>=0.0.14 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealtimeSTT) (0.0.14)
# Requirement already satisfied: spinners>=0.0.24 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealtimeSTT) (0.0.24)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealtimeSTT) (3.3.0)
# Requirement already satisfied: colorama>=0.3.9 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealtimeSTT) (0.4.6)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from halo==0.0.31->RealtimeSTT) (1.17.0)
# Requirement already satisfied: enum34 in /opt/anaconda3/lib/python3.13/site-packages (from pvporcupine==1.9.5->RealtimeSTT) (1.1.10)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from pvporcupine==1.9.5->RealtimeSTT) (2.1.3)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/lib/python3.13/site-packages (from soundfile==0.13.1->RealtimeSTT) (1.17.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1->RealtimeSTT) (82.0.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in /opt/anaconda3/lib/python3.13/site-packages (from ctranslate2<5,>=4.0->faster-whisper==1.1.1->RealtimeSTT) (6.0.2)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealtimeSTT) (25.12.19)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealtimeSTT) (24.2)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealtimeSTT) (6.33.5)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealtimeSTT) (1.13.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (0.28.1)
# Requirement already satisfied: shellingham in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (1.5.0)
# Requirement already satisfied: typer-slim in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (4.15.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (4.12.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (0.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.0->soundfile==0.13.1->RealtimeSTT) (2.21)
# Requirement already satisfied: scikit-learn<2,>=1 in /opt/anaconda3/lib/python3.13/site-packages (from openwakeword>=0.4.0->RealtimeSTT) (1.6.1)
# Requirement already satisfied: requests<3,>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from openwakeword>=0.4.0->RealtimeSTT) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0->openwakeword>=0.4.0->RealtimeSTT) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.0->openwakeword>=0.4.0->RealtimeSTT) (2.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2,>=1->openwakeword>=0.4.0->RealtimeSTT) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2,>=1->openwakeword>=0.4.0->RealtimeSTT) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper==1.1.1->RealtimeSTT) (1.3.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch->RealtimeSTT) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch->RealtimeSTT) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch->RealtimeSTT) (3.0.2)
# Requirement already satisfied: typer>=0.24.0 in /opt/anaconda3/lib/python3.13/site-packages (from typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.13->faster-whisper==1.1.1->RealtimeSTT) (0.1.0)

# %%
from RealtimeSTT import AudioToTextRecorder

def process_text(text):
    print(f"User said: {text}")

recorder = AudioToTextRecorder(model = "tiny.en", language = "en")

print(f"I'm listening...")

while True:
    recorder.text(process_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from RealtimeSTT import AudioToTextRecorder
#       3 def process_text(text):
#       4     print(f"User said: {text}")
#
# File /opt/anaconda3/lib/python3.13/site-packages/RealtimeSTT/__init__.py:1
# ----> 1 from .audio_recorder import AudioToTextRecorder
#       2 from .audio_recorder_client import AudioToTextRecorderClient
#       3 from .audio_input import AudioInput
#
# File /opt/anaconda3/lib/python3.13/site-packages/RealtimeSTT/audio_recorder.py:31
#      29 from faster_whisper import WhisperModel, BatchedInferencePipeline
#      30 from typing import Iterable, List, Optional, Union
# ---> 31 from openwakeword.model import Model
#      32 import torch.multiprocessing as mp
#      33 from scipy.signal import resample
#
# File /opt/anaconda3/lib/python3.13/site-packages/openwakeword/__init__.py:4
#       2 from openwakeword.model import Model
#       3 from openwakeword.vad import VAD
# ----> 4 from openwakeword.custom_verifier_model import train_custom_verifier
#       6 __all__ = ['Model', 'VAD', 'train_custom_verifier']
#       8 FEATURE_MODELS = {
#       9     "embedding": {
#      10         "model_path": os.path.join(os.path.dirname(os.path.abspath(__file__)), "resources/models/embedding_model.tflite"),
#    (...)
#      16     }
#      17 }
#
# File /opt/anaconda3/lib/python3.13/site-packages/openwakeword/custom_verifier_model.py:24
#      21 import scipy
#      22 import pickle
# ---> 24 from sklearn.linear_model import LogisticRegression
#      25 from sklearn.pipeline import make_pipeline
#      26 from sklearn.preprocessing import FunctionTransformer, StandardScaler
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)
#     114     "compose",
#     115 ]
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/__init__.py:15
#      13 from . import _joblib, metadata_routing
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#      18 # Make _safe_indexing importable from here for backward compat as this particular
#      19 # helper is considered semi-private and typically very useful for third-party
#      20 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      21 # _safe_indexing was included in our public API documentation despite the leading
#      22 # `_` in its name.
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:14
#      11 from numbers import Integral, Real
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
#      17 from .validation import _is_arraylike_not_scalar
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/sparse/__init__.py:315
#     312 from ._sputils import get_index_dtype, safely_cast_index_arrays
#     314 # For backward compatibility with v0.19.
# --> 315 from . import csgraph
#     317 # Deprecated namespaces, to be removed in v2.0.0
#     318 from . import (
#     319     base, bsr, compressed, construct, coo, csc, csr, data, dia, dok, extract,
#     320     lil, sparsetools, sputils
#     321 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/sparse/csgraph/__init__.py:187
#     158 __docformat__ = "restructuredtext en"
#     160 __all__ = ['connected_components',
#     161            'laplacian',
#     162            'shortest_path',
#    (...)
#     184            'csgraph_to_masked',
#     185            'NegativeCycleError']
# --> 187 from ._laplacian import laplacian
#     188 from ._shortest_path import (
#     189     shortest_path, floyd_warshall, dijkstra, bellman_ford, johnson, yen,
#     190     NegativeCycleError
#     191 )
#     192 from ._traversal import (
#     193     breadth_first_order, depth_first_order, breadth_first_tree,
#     194     depth_first_tree, connected_components
#     195 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/sparse/csgraph/_laplacian.py:7
#       5 import numpy as np
#       6 from scipy.sparse import issparse
# ----> 7 from scipy.sparse.linalg import LinearOperator
#       8 from scipy.sparse._sputils import convert_pydata_sparse_to_scipy, is_pydata_spmatrix
#      11 ###############################################################################
#      12 # Graph laplacian
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/sparse/linalg/__init__.py:131
#       1 """
#       2 Sparse linear algebra (:mod:`scipy.sparse.linalg`)
#       3 ==================================================
#    (...)
#     128
#     129 """
# --> 131 from ._isolve import *
#     132 from ._dsolve import *
#     133 from ._interface import *
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/sparse/linalg/_isolve/__init__.py:4
#       1 "Iterative Solvers for Sparse Linear Systems"
#       3 #from info import __doc__
# ----> 4 from .iterative import *
#       5 from .minres import minres
#       6 from .lgmres import lgmres
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/sparse/linalg/_isolve/iterative.py:5
#       3 from scipy.sparse.linalg._interface import LinearOperator
#       4 from .utils import make_system
# ----> 5 from scipy.linalg import get_lapack_funcs
#       7 __all__ = ['bicg', 'bicgstab', 'cg', 'cgs', 'gmres', 'qmr']
#      10 def _get_atol_rtol(name, b_norm, atol=0., rtol=1e-5):
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/linalg/__init__.py:207
#     205 from ._basic import *
#     206 from ._decomp import *
# --> 207 from ._decomp_lu import *
#     208 from ._decomp_ldl import *
#     209 from ._decomp_cholesky import *
#
# File /opt/anaconda3/lib/python3.13/site-packages/scipy/linalg/_decomp_lu.py:12
#      10 from ._misc import _datacopied, LinAlgWarning
#      11 from .lapack import get_lapack_funcs
# ---> 12 from ._decomp_lu_cython import lu_dispatcher
#      14 lapack_cast_dict = {x: ''.join([y for y in 'fdFD' if np.can_cast(x, y)])
#      15                     for x in np.typecodes['All']}
#      17 __all__ = ['lu', 'lu_solve', 'lu_factor']
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:
